# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
df=pd.read_excel(r'C:\Users\FLUTE\Dropbox\Project\Load.xlsx')
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Convert the date column to datetime format
df1['Months'] = pd.to_datetime(df['Months'])

# %%
# Set the date column as the index
df1.set_index('Months', inplace=True)

# %%
# Plot the time series data
plt.plot(df1)
plt.xlabel('Months')
plt.ylabel('Value')
plt.title('Time Series Data')
plt.show()

# %%
df1.plot(figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='Months'>

# %%
# Perform time series decomposition into trend, seasonality, and residuals
decomposition = sm.tsa.seasonal_decompose(df1, model='additive')
trend = decomposition.trend
seasonality = decomposition.seasonal
residuals = decomposition.resid
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3972/1383164101.py in <module>
#       1 # Perform time series decomposition into trend, seasonality, and residuals
# ----> 2 decomposition = sm.tsa.seasonal_decompose(df1, model='additive')
#       3 trend = decomposition.trend
#       4 seasonality = decomposition.seasonal
#       5 residuals = decomposition.resid
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     205                 else:
#     206                     kwargs[new_arg_name] = new_arg_value
# --> 207             return func(*args, **kwargs)
#     208
#     209         return cast(F, wrapper)
#
# ~\anaconda3\lib\site-packages\statsmodels\tsa\seasonal.py in seasonal_decompose(x, model, filt, period, two_sided, extrapolate_trend)
#     141             period = pfreq
#     142         else:
# --> 143             raise ValueError("You must specify a period or x must be a "
#     144                              "pandas object with a DatetimeIndex with "
#     145                              "a freq not set to None")
#
# ValueError: You must specify a period or x must be a pandas object with a DatetimeIndex with a freq not set to None
